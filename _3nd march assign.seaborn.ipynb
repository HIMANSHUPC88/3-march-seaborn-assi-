# %% [markdown]
# # Que 1: Name any five plots that we can plot using the Seaborn library. Also, state the uses of each plot.

# %%
1. Scatterplot  
    uses - Scatter plot uses the point to represents the relation between two different variables.
2. displot
   uses - Distributive plot is just like Histogram , Distributive plot is used to visulize the distribution the single variable. 
3. jointplot
   uses - joint plot is used to show relationship between two variables in a dataset. it create the multi-pannel figure to display both indivisiual distribution 
    of the variables and their joint distribution.    
4. pairplot
   uses - pair plot is used to visulize the relationships between multiple variables in a dataset.
5. catplot
   uses - catplot is used to visulize relationship between variables in a dataset.
    these are all of those five plots which we can use in the Seaborn library.

# %% [markdown]
# #  Que 2: Load the "fmri" dataset using the load_dataset function of seaborn. Plot a line plot using x = "timepoint" and y = "signal" for different events and regions.
#
# # Note:  timepoint, signal, event, and region are columns in the fmri dataset

# %%
import seaborn as sns

# %%
fmri = sns.load_dataset("fmri")

# %%
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.lineplot(x = fmri.timepoint, y = fmri.signal , data = fmri ,  hue ="region" , style =  "event" )
# Out:
# <AxesSubplot: xlabel='timepoint', ylabel='signal'>

# %% [markdown]
# # Que 3: Load the "titanic" dataset using the load_dataset function of seaborn. Plot two box plots using x = 'pclass', y = 'age' and y = 'fare'.
#
# # Note:  pclass, age, and fare are columns in the titanic dataset.

# %%
titanic = sns.load_dataset("titanic")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
titanic = sns.load_dataset('titanic')
plt.subplot(1,2,1)
sns.boxplot(x = titanic.pclass, y = titanic.fare , data = titanic)

plt.subplot(1,2,2)
sns.boxplot(x = titanic.pclass, y = titanic.age , data = titanic )
# Out:
# <AxesSubplot: xlabel='pclass', ylabel='age'>

# %% [markdown]
# # Que 4: Use the "diamonds" dataset from seaborn to plot a histogram for the 'price' column. Use the hue parameter for the 'cut' column of the diamonds dataset.

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

diamonds = sns.load_dataset("diamonds")

plt.figure(figsize=(10,6))

sns.histplot( x = 'price' ,  hue = 'cut' , data = diamonds , bins=30, kde=True)
plt.show()

# %% [markdown]
# # Que 5: Use the "iris" dataset from seaborn to plot a pair plot. Use the hue parameter for the "species" column of the iris dataset.

# %%
iris = sns.load_dataset("iris")

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(hue = 'species' , data = iris)

# %% [markdown]
# # Que 6: Use the "flights" dataset from seaborn to plot a heatmap.

# %%
flights = sns.load_dataset('flights')

# %%
sns.heatmap(data=flights.pivot('month', 'year', 'passengers'), annot=True, fmt='d', cmap='coolwarm')
# Out:
# /tmp/ipykernel_91/2828690683.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   sns.heatmap(data=flights.pivot('month', 'year', 'passengers'), annot=True, fmt='d', cmap='coolwarm')
# <AxesSubplot: xlabel='year', ylabel='month'>
